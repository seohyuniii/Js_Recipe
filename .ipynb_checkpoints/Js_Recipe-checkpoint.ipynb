# %% [markdown]
# # 라이브러리 및 데이터 불러오기

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, time

# 데이터 시각화를 위한 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')  # matplotlib style 설정

# 한글 폰트를 적용하는 코드
import matplotlib
import matplotlib.font_manager as fm
fm._rebuild()
fm.get_fontconfig_fonts()
font_location = 'data/NanumBarunGothic.ttf' # 폰트 파일 이름, 디렉토리 주의
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)

# 문법 변경에 의한 경고를 무시
import warnings

warnings.filterwarnings('ignore')

# matplotlib 시각화 결과를 jupyter notebook에서 바로 볼 수 있게 해주는 command
# %matplotlib inline

# %%
# 데이터 불러오기
js_q1=pd.read_excel('data/coupang_eats_2021-Q1.xlsx')
js_q2=pd.read_excel('data/coupang_eats_2021-Q2.xlsx')
js_q3=pd.read_excel('data/coupang_eats_2021-Q3.xlsx')

# %% [markdown]
# **2021.01.01 ~ 2021.09.30**

# %% [markdown]
# # Data Cleansing

# %% [markdown]
# ## Q1

# %%
js_q1.head()
# Out:
#           거래일                거래일시    결제유형   주문아이디  브랜드명     상점명 거래유형  \
# 0         NaN                 NaT     NaN     NaN   NaN     NaN  NaN
# 1  2021-01-01 2021-01-01 12:03:57  CREDIT  2VUCR0   NaN  제이스레시피  PAY
# 2  2021-01-01 2021-01-01 12:10:50  CREDIT  1BW780   NaN  제이스레시피  PAY
# 3  2021-01-01 2021-01-01 14:29:07   CHECK  2RJPG0   NaN  제이스레시피  PAY
# 4  2021-01-01 2021-01-01 14:46:06  CREDIT  17XM80   NaN  제이스레시피  PAY
#
#                                                 주문내역      총금액     주문금액  ...  \
# 0                                                NaN      NaN      NaN  ...
# 1                          치아바타, 블랙올리브 치아바타, 바게트, 스콘  15200.0  12200.0  ...
# 2           뺑오쇼콜라x2, 크로와상, 치아바타, 먹물 유자 크림치즈, 크렌베리 스콘  22200.0  19200.0  ...
# 3           스콘, 치아바타x2, 호두 크렌베리 캉파뉴, 올리브오일, 레몬 마들렌x2  20000.0  17000.0  ...
# 4  크렌베리 스콘x2, 크렌베리 치아바타x2, 먹물 유자 크림치즈, 아몬드 크로와상, ...  24700.0  21700.0  ...
#
#      기본요금    Unnamed: 14  Unnamed: 15   프로모션요금 Unnamed: 17 고객부담배달비 프로모션혜택금액  \
# 0  서비스수수료  카드수수료 및 결제이용료        배달수수료  주문중개수수료        배달요금     NaN      NaN
# 1    1830            366         6000     1000        5000  2727.0   4557.0
# 2    2880            576         6000     1000        5000  2727.0   5607.0
# 3    2550            510         6000     1000        5000  2727.0   5277.0
# 4    3255            651         6000     1000        5000  2727.0   5982.0
#
#     최종요금  Unnamed: 21     정산금액
# 0  총공급가액        총부가세액      NaN
# 1   3639          364   8197.0
# 2   3849          385  14966.0
# 3   3783          378  12839.0
# 4   3924          392  17384.0
#
# [5 rows x 23 columns]

# %%
js_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   거래일          178 non-null    object
#  1   거래일시         178 non-null    datetime64[ns]
#  2   결제유형         178 non-null    object
#  3   주문아이디        178 non-null    object
#  4   브랜드명         0 non-null      float64
#  5   상점명          178 non-null    object
#  6   거래유형         178 non-null    object
#  7   주문내역         178 non-null    object
#  8   총금액          178 non-null    float64
#  9   주문금액         178 non-null    float64
#  10  결제금액         178 non-null    float64
#  11  쿠팡부담할인금액     178 non-null    float64
#  12  상점부담할인금액     178 non-null    float64
#  13  기본요금         179 non-null    object
#  14  Unnamed: 14  179 non-null    object
#  15  Unnamed: 15  179 non-null    object
#  16  프로모션요금       179 non-null    object
#  17  Unnamed: 17  179 non-null    object
#  18  고객부담배달비      178 non-null    float64
#  19  프로모션혜택금액     178 non-null    float64
#  20  최종요금         179 non-null    object
#  21  Unnamed: 21  179 non-null    object
#  22  정산금액         178 non-null    float64
# dtypes: datetime64[ns](1), float64(9), object(13)
# memory usage: 32.3+ KB

# %% [markdown]
# **js_q1**
# - 거래일, 브랜드명, 상점명 drop
# - 기본요금 -> 서비스수수료, Unnamed: 14 -> 카드수수료_결제이용료, Unnamed: 15 -> 배달수수료, 프로모션요금 -> 주문중개수수료, Unnamed: 17 -> 배달요금, 최종요금 -> 총공급가액, Unnamed: 21 -> 총부가세액
# - 0행 지우기

# %%
# 불필요한 행 drop
js_q1.drop(['거래일', '브랜드명', '상점명'], axis=1, inplace=True)

# %%
# 열 이름 변경
js_q1.rename(columns={'기본요금':'서비스수수료', 'Unnamed: 14':'카드수수료_결제이용료', 'Unnamed: 15':'배달수수료',
                      '프로모션요금':'주문중개수수료', 'Unnamed: 17':'배달요금', '최종요금':'총공급가액', 'Unnamed: 21':'총부가세액'}, inplace=True)
js_q1.drop(0, axis=0, inplace=True)

# %%
# q2, q3에 맞춰 최종요금 총액 행 만들기
js_q1['최종요금총액']=js_q1.총공급가액+js_q1.총부가세액

# %%
# 행 정렬
temp=js_q1.정산금액
js_q1.drop(['정산금액'], axis=1, inplace=True)
js_q1.loc[:,'정산금액']=temp

# %%
# 고객 부담 배달비 총액이 3000원이므로 고객부담배달비 열을 '고객부담배달비총액' 으로 변경후 +/- 3000으로 변경
js_q1.rename(columns={'고객부담배달비':'고객부담배달비총액'}, inplace=True)
js_q1['고객부담배달비총액']=js_q1['고객부담배달비총액'].apply(lambda x: 3000 if (x>0) else -3000).astype('float')

# %%
js_q1.reset_index(drop=True, inplace=True)

# %%
js_q1.head()
# Out:
#                  거래일시    결제유형   주문아이디 거래유형  \
# 0 2021-01-01 12:03:57  CREDIT  2VUCR0  PAY
# 1 2021-01-01 12:10:50  CREDIT  1BW780  PAY
# 2 2021-01-01 14:29:07   CHECK  2RJPG0  PAY
# 3 2021-01-01 14:46:06  CREDIT  17XM80  PAY
# 4 2021-01-01 16:39:16    BANK  2RVT80  PAY
#
#                                                 주문내역      총금액     주문금액  \
# 0                          치아바타, 블랙올리브 치아바타, 바게트, 스콘  15200.0  12200.0
# 1           뺑오쇼콜라x2, 크로와상, 치아바타, 먹물 유자 크림치즈, 크렌베리 스콘  22200.0  19200.0
# 2           스콘, 치아바타x2, 호두 크렌베리 캉파뉴, 올리브오일, 레몬 마들렌x2  20000.0  17000.0
# 3  크렌베리 스콘x2, 크렌베리 치아바타x2, 먹물 유자 크림치즈, 아몬드 크로와상, ...  24700.0  21700.0
# 4                     먹물 치즈 치아바타, 뺑오쇼콜라, 크렌베리 치아바타x2  16200.0  13200.0
#
#       결제금액  쿠팡부담할인금액  상점부담할인금액  ... 카드수수료_결제이용료 배달수수료 주문중개수수료  배달요금 고객부담배달비총액  \
# 0  13200.0    2000.0       0.0  ...         366  6000    1000  5000    3000.0
# 1  20200.0    2000.0       0.0  ...         576  6000    1000  5000    3000.0
# 2  18000.0    2000.0       0.0  ...         510  6000    1000  5000    3000.0
# 3  22700.0    2000.0       0.0  ...         651  6000    1000  5000    3000.0
# 4  14200.0    2000.0       0.0  ...         396  6000    1000  5000    3000.0
#
#    프로모션혜택금액  총공급가액 총부가세액 최종요금총액     정산금액
# 0    4557.0   3639   364   4003   8197.0
# 1    5607.0   3849   385   4234  14966.0
# 2    5277.0   3783   378   4161  12839.0
# 3    5982.0   3924   392   4316  17384.0
# 4    4707.0   3669   367   4036   9164.0
#
# [5 rows x 21 columns]

# %%
js_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   거래일시         178 non-null    datetime64[ns]
#  1   결제유형         178 non-null    object
#  2   주문아이디        178 non-null    object
#  3   거래유형         178 non-null    object
#  4   주문내역         178 non-null    object
#  5   총금액          178 non-null    float64
#  6   주문금액         178 non-null    float64
#  7   결제금액         178 non-null    float64
#  8   쿠팡부담할인금액     178 non-null    float64
#  9   상점부담할인금액     178 non-null    float64
#  10  서비스수수료       178 non-null    object
#  11  카드수수료_결제이용료  178 non-null    object
#  12  배달수수료        178 non-null    object
#  13  주문중개수수료      178 non-null    object
#  14  배달요금         178 non-null    object
#  15  고객부담배달비총액    178 non-null    float64
#  16  프로모션혜택금액     178 non-null    float64
#  17  총공급가액        178 non-null    object
#  18  총부가세액        178 non-null    object
#  19  최종요금총액       178 non-null    object
#  20  정산금액         178 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(12)
# memory usage: 29.3+ KB

# %% [markdown]
# ## Q2

# %%
js_q2.head()
# Out:
#           거래일                거래일시   결제유형   주문아이디  브랜드명     상점명 거래유형  \
# 0         NaN                 NaT    NaN     NaN   NaN     NaN  NaN
# 1  2021-04-01 2021-04-01 14:02:12  CHECK  1BPC80   NaN  제이스레시피  PAY
# 2  2021-04-01 2021-04-01 16:27:36  CHECK  1TBK00   NaN  제이스레시피  PAY
# 3  2021-04-02 2021-04-02 14:47:50   BANK  1S3080   NaN  제이스레시피  PAY
# 4  2021-04-03 2021-04-03 12:53:39  CHECK  2K6A00   NaN  제이스레시피  PAY
#
#                                                 주문내역      총금액     주문금액  ...  \
# 0                                                NaN      NaN      NaN  ...
# 1                           바게트x2, 호두 크렌베리 캉파뉴, 치아바타  17000.0  14000.0  ...
# 2             호두 크렌베리 캉파뉴, 초코 브리오슈, 아메리카노, 멀티그레인 빵드미  18900.0  15900.0  ...
# 3  먹물 유자 크림치즈x2, 먹물 치즈 치아바타x2, 녹차 스콘, 무화과 사워도우, 치...  34800.0  31800.0  ...
# 4                  블랙올리브 치아바타, 크렌베리 스콘, 먹물 치즈 치아바타x2  18000.0  15000.0  ...
#
#    Unnamed: 15   프로모션요금  Unnamed: 17 고객부담배달비 고객부담배달비 (총액) 프로모션혜택금액   최종요금  \
# 0        배달수수료  주문중개수수료         배달요금     NaN          NaN      NaN  총공급가액
# 1         6000     1000         5000  2727.0       3000.0   4827.0   3693
# 2         6000     1000         5000  2727.0       3000.0   5112.0   3750
# 3         6000     1000         5000  2727.0       3000.0   7497.0   4227
# 4         6000     1000         5000  2727.0       3000.0   4977.0   3723
#
#   Unnamed: 22  Unnamed: 23     정산금액
# 0       총부가세액           총액      NaN
# 1         369         4062   9938.0
# 2         375         4125  11775.0
# 3         422         4649  27151.0
# 4         372         4095  10905.0
#
# [5 rows x 25 columns]

# %%
js_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   거래일           264 non-null    object
#  1   거래일시          264 non-null    datetime64[ns]
#  2   결제유형          264 non-null    object
#  3   주문아이디         264 non-null    object
#  4   브랜드명          0 non-null      float64
#  5   상점명           264 non-null    object
#  6   거래유형          264 non-null    object
#  7   주문내역          264 non-null    object
#  8   총금액           264 non-null    float64
#  9   주문금액          264 non-null    float64
#  10  결제금액          264 non-null    float64
#  11  쿠팡부담할인금액      264 non-null    float64
#  12  상점부담할인금액      264 non-null    float64
#  13  기본요금          265 non-null    object
#  14  Unnamed: 14   265 non-null    object
#  15  Unnamed: 15   265 non-null    object
#  16  프로모션요금        265 non-null    object
#  17  Unnamed: 17   265 non-null    object
#  18  고객부담배달비       264 non-null    float64
#  19  고객부담배달비 (총액)  264 non-null    float64
#  20  프로모션혜택금액      264 non-null    float64
#  21  최종요금          265 non-null    object
#  22  Unnamed: 22   265 non-null    object
#  23  Unnamed: 23   265 non-null    object
#  24  정산금액          264 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(14)
# memory usage: 51.9+ KB

# %% [markdown]
# **js_q2**
# - 거래일, 브랜드명, 상점명 고객부담배달비 drop
# - 기본요금 -> 서비스수수료, Unnamed: 14 -> 카드수수료_결제이용료, Unnamed: 15 -> 배달수수료, 프로모션요금 -> 주문중개수수료, Unnamed: 17 -> 배달요금, 고객부담배달비 (총액) -> 고객부담배달비총액, 최종요금 -> 총공급가액, Unnamed: 22 -> 총부가세액, Unnamed: 23 -> 최종요금총액
# - 0행 지우기

# %%
# 불필요한 행 drop
js_q2.drop(['거래일', '브랜드명', '상점명', '고객부담배달비'], axis=1, inplace=True)

# %%
# 행 이름 변경
js_q2.rename(columns={'기본요금':'서비스수수료', 'Unnamed: 14':'카드수수료_결제이용료', 'Unnamed: 15':'배달수수료',
                      '프로모션요금':'주문중개수수료', 'Unnamed: 17':'배달요금', '고객부담배달비 (총액)':'고객부담배달비총액',
                      '최종요금':'총공급가액', 'Unnamed: 22':'총부가세액', 'Unnamed: 23':'최종요금총액'}, inplace=True)
js_q2.drop(0, axis=0, inplace=True)

# %%
js_q2.reset_index(drop=True, inplace=True)

# %%
js_q2.head()
# Out:
#                  거래일시   결제유형   주문아이디 거래유형  \
# 0 2021-04-01 14:02:12  CHECK  1BPC80  PAY
# 1 2021-04-01 16:27:36  CHECK  1TBK00  PAY
# 2 2021-04-02 14:47:50   BANK  1S3080  PAY
# 3 2021-04-03 12:53:39  CHECK  2K6A00  PAY
# 4 2021-04-03 12:55:31   BANK  1KDAG0  PAY
#
#                                                 주문내역      총금액     주문금액  \
# 0                           바게트x2, 호두 크렌베리 캉파뉴, 치아바타  17000.0  14000.0
# 1             호두 크렌베리 캉파뉴, 초코 브리오슈, 아메리카노, 멀티그레인 빵드미  18900.0  15900.0
# 2  먹물 유자 크림치즈x2, 먹물 치즈 치아바타x2, 녹차 스콘, 무화과 사워도우, 치...  34800.0  31800.0
# 3                  블랙올리브 치아바타, 크렌베리 스콘, 먹물 치즈 치아바타x2  18000.0  15000.0
# 4                 크렌베리 치아바타, 병아리콩 치아바타x2, 먹물 치즈 치아바타  15600.0  12600.0
#
#       결제금액  쿠팡부담할인금액  상점부담할인금액  ... 카드수수료_결제이용료 배달수수료 주문중개수수료  배달요금 고객부담배달비총액  \
# 0  14000.0    3000.0       0.0  ...         420  6000    1000  5000    3000.0
# 1  17900.0    1000.0       0.0  ...         477  6000    1000  5000    3000.0
# 2  34800.0       0.0       0.0  ...         954  6000    1000  5000    3000.0
# 3  18000.0       0.0       0.0  ...         450  6000    1000  5000    3000.0
# 4  15600.0       0.0       0.0  ...         378  6000    1000  5000    3000.0
#
#    프로모션혜택금액  총공급가액 총부가세액 최종요금총액     정산금액
# 0    4827.0   3693   369   4062   9938.0
# 1    5112.0   3750   375   4125  11775.0
# 2    7497.0   4227   422   4649  27151.0
# 3    4977.0   3723   372   4095  10905.0
# 4    4617.0   3651   365   4016   8584.0
#
# [5 rows x 21 columns]

# %%
js_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   거래일시         264 non-null    datetime64[ns]
#  1   결제유형         264 non-null    object
#  2   주문아이디        264 non-null    object
#  3   거래유형         264 non-null    object
#  4   주문내역         264 non-null    object
#  5   총금액          264 non-null    float64
#  6   주문금액         264 non-null    float64
#  7   결제금액         264 non-null    float64
#  8   쿠팡부담할인금액     264 non-null    float64
#  9   상점부담할인금액     264 non-null    float64
#  10  서비스수수료       264 non-null    object
#  11  카드수수료_결제이용료  264 non-null    object
#  12  배달수수료        264 non-null    object
#  13  주문중개수수료      264 non-null    object
#  14  배달요금         264 non-null    object
#  15  고객부담배달비총액    264 non-null    float64
#  16  프로모션혜택금액     264 non-null    float64
#  17  총공급가액        264 non-null    object
#  18  총부가세액        264 non-null    object
#  19  최종요금총액       264 non-null    object
#  20  정산금액         264 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(12)
# memory usage: 43.4+ KB

# %% [markdown]
# ## Q3

# %%
js_q3.head()
# Out:
#           거래일                거래일시 주문유형    결제유형   주문아이디  브랜드명     상점명 거래유형  \
# 0         NaN                 NaT  NaN     NaN     NaN   NaN     NaN  NaN
# 1  2021-07-02 2021-07-02 16:56:35   배달  CREDIT  1TLG00   NaN  제이스레시피  PAY
# 2  2021-07-02 2021-07-02 19:01:48   배달  CREDIT  1DSLR0   NaN  제이스레시피  PAY
# 3  2021-07-03 2021-07-03 12:03:27   배달  CREDIT  2WLXR0   NaN  제이스레시피  PAY
# 4  2021-07-03 2021-07-03 13:36:42   배달  CREDIT  1B2PR0   NaN  제이스레시피  PAY
#
#                                           주문내역      총금액  ...  고객부담배달비  \
# 0                                          NaN      NaN  ...      NaN
# 1      스콘, 크렌베리 스콘, 아몬드 크로와상, 카페라떼, 먹물 치즈 치아바타  21800.0  ...   2727.0
# 2  호두 크렌베리 캉파뉴, 곡물 치아바타, 병아리콩 치아바타, 먹물 치즈 치아바타  17700.0  ...   2727.0
# 3                병아리콩 치아바타, 체다치즈, 녹차 스콘, 초코 스콘  18400.0  ...   2727.0
# 4             카페라떼, 아메리카노, 병아리콩 치아바타, 아몬드 크로와상  17000.0  ...   2727.0
#
#    고객부담배달비 (총액)  프로모션혜택금액   최종요금 Unnamed: 23 Unnamed: 24    광고비 Unnamed: 26  \
# 0           NaN       NaN  총공급가액       총부가세액          총액  총공급가액       총부가세액
# 1        3000.0    5547.0   3837         383        4220      0           0
# 2        3000.0    4932.0   3714         371        4085      0           0
# 3        3000.0    4587.0   3645         364        4009      0           0
# 4        3000.0    4827.0   3693         369        4062      0           0
#
#   Unnamed: 27     정산금액
# 0          총액      NaN
# 1           0  14580.0
# 2           0  10615.0
# 3           0   8391.0
# 4           0   9938.0
#
# [5 rows x 29 columns]

# %%
js_q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   거래일           271 non-null    object
#  1   거래일시          271 non-null    datetime64[ns]
#  2   주문유형          271 non-null    object
#  3   결제유형          271 non-null    object
#  4   주문아이디         271 non-null    object
#  5   브랜드명          0 non-null      float64
#  6   상점명           271 non-null    object
#  7   거래유형          271 non-null    object
#  8   주문내역          271 non-null    object
#  9   총금액           271 non-null    float64
#  10  주문금액          271 non-null    float64
#  11  결제금액          271 non-null    float64
#  12  쿠팡부담할인금액      271 non-null    float64
#  13  상점부담할인금액      271 non-null    float64
#  14  기본요금          272 non-null    object
#  15  Unnamed: 15   272 non-null    object
#  16  Unnamed: 16   272 non-null    object
#  17  프로모션요금        272 non-null    object
#  18  Unnamed: 18   272 non-null    object
#  19  고객부담배달비       271 non-null    float64
#  20  고객부담배달비 (총액)  271 non-null    float64
#  21  프로모션혜택금액      271 non-null    float64
#  22  최종요금          272 non-null    object
#  23  Unnamed: 23   272 non-null    object
#  24  Unnamed: 24   272 non-null    object
#  25  광고비           272 non-null    object
#  26  Unnamed: 26   272 non-null    object
#  27  Unnamed: 27   272 non-null    object
#  28  정산금액          271 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(18)
# memory usage: 61.8+ KB

# %% [markdown]
# **js_q3**
# - 거래일, 주문유형, 브랜드명, 상점명, 고객부담배달비, 광고비, Unnamed: 26, Unnamed: 27 drop
# - 기본요금 -> 서비스수수료, Unnamed: 15 -> 카드수수료_결제이용료, Unnamed: 16 -> 배달수수료, 프로모션요금 -> 주문중개수수료, Unnamed: 18 -> 배달요금, 고객부담배달비 (총액) -> 고객부담배달비총액, 최종요금 -> 총공급가액, Unnamed: 23 -> 총부가세액, Unnamed: 24 -> 최종요금총액
# - 0행 지우기

# %%
# 불필요한 행 drop
js_q3.drop(['거래일', '주문유형', '브랜드명', '상점명','고객부담배달비', '광고비', 'Unnamed: 26', 'Unnamed: 27'], axis=1, inplace=True)

# %%
# 행 이름 변경
js_q3.rename(columns={'기본요금':'서비스수수료', 'Unnamed: 15':'카드수수료_결제이용료', 'Unnamed: 16':'배달수수료',
                      '프로모션요금':'주문중개수수료', 'Unnamed: 18':'배달요금', '고객부담배달비 (총액)':'고객부담배달비총액',
                      '최종요금':'총공급가액', 'Unnamed: 23':'총부가세액', 'Unnamed: 24':'최종요금총액'}, inplace=True)
js_q3.drop(0, axis=0, inplace=True)

# %%
js_q3.reset_index(drop=True, inplace=True)

# %%
js_q3.head()
# Out:
#                  거래일시    결제유형   주문아이디 거래유형  \
# 0 2021-07-02 16:56:35  CREDIT  1TLG00  PAY
# 1 2021-07-02 19:01:48  CREDIT  1DSLR0  PAY
# 2 2021-07-03 12:03:27  CREDIT  2WLXR0  PAY
# 3 2021-07-03 13:36:42  CREDIT  1B2PR0  PAY
# 4 2021-07-03 15:09:42   CHECK  232FG0  PAY
#
#                                           주문내역      총금액     주문금액     결제금액  \
# 0      스콘, 크렌베리 스콘, 아몬드 크로와상, 카페라떼, 먹물 치즈 치아바타  21800.0  18800.0  18800.0
# 1  호두 크렌베리 캉파뉴, 곡물 치아바타, 병아리콩 치아바타, 먹물 치즈 치아바타  17700.0  14700.0  17700.0
# 2                병아리콩 치아바타, 체다치즈, 녹차 스콘, 초코 스콘  18400.0  12400.0  18400.0
# 3             카페라떼, 아메리카노, 병아리콩 치아바타, 아몬드 크로와상  17000.0  14000.0  17000.0
# 4                         스콘x2, 크렌베리 스콘, 뺑오쇼콜라  15600.0  12600.0  15600.0
#
#    쿠팡부담할인금액  상점부담할인금액  ... 카드수수료_결제이용료 배달수수료 주문중개수수료  배달요금 고객부담배달비총액  \
# 0    3000.0       0.0  ...         564  6000    1000  5000    3000.0
# 1       0.0       0.0  ...         441  6000    1000  5000    3000.0
# 2       0.0       0.0  ...         372  6000    1000  5000    3000.0
# 3       0.0       0.0  ...         420  6000    1000  5000    3000.0
# 4       0.0       0.0  ...         378  6000    1000  5000    3000.0
#
#    프로모션혜택금액  총공급가액 총부가세액 최종요금총액     정산금액
# 0    5547.0   3837   383   4220  14580.0
# 1    4932.0   3714   371   4085  10615.0
# 2    4587.0   3645   364   4009   8391.0
# 3    4827.0   3693   369   4062   9938.0
# 4    4617.0   3651   365   4016   8584.0
#
# [5 rows x 21 columns]

# %%
js_q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   거래일시         271 non-null    datetime64[ns]
#  1   결제유형         271 non-null    object
#  2   주문아이디        271 non-null    object
#  3   거래유형         271 non-null    object
#  4   주문내역         271 non-null    object
#  5   총금액          271 non-null    float64
#  6   주문금액         271 non-null    float64
#  7   결제금액         271 non-null    float64
#  8   쿠팡부담할인금액     271 non-null    float64
#  9   상점부담할인금액     271 non-null    float64
#  10  서비스수수료       271 non-null    object
#  11  카드수수료_결제이용료  271 non-null    object
#  12  배달수수료        271 non-null    object
#  13  주문중개수수료      271 non-null    object
#  14  배달요금         271 non-null    object
#  15  고객부담배달비총액    271 non-null    float64
#  16  프로모션혜택금액     271 non-null    float64
#  17  총공급가액        271 non-null    object
#  18  총부가세액        271 non-null    object
#  19  최종요금총액       271 non-null    object
#  20  정산금액         271 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(12)
# memory usage: 44.6+ KB

# %%
js_q3.columns
# Out:
# Index(['거래일시', '결제유형', '주문아이디', '거래유형', '주문내역', '총금액', '주문금액', '결제금액',
#        '쿠팡부담할인금액', '상점부담할인금액', '서비스수수료', '카드수수료_결제이용료', '배달수수료', '주문중개수수료',
#        '배달요금', '고객부담배달비총액', '프로모션혜택금액', '총공급가액', '총부가세액', '최종요금총액', '정산금액'],
#       dtype='object')

# %% [markdown]
# - 세 개 쿼터 합치기
# - 거래일시 시간별로 오전 오후 나누기(12시 ~ 20시 -> 12 ~ 16:59 / 17~20)
# - 서비스수수료+카드수수료_결제이용료+(배달수수료-프로모션혜택금액)=>총공급가액
# - 주문금액-최종요금총액 => 정산금액

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# **Columns**<br>
# '거래일시', '결제유형', '주문아이디', '거래유형', '주문내역', '총금액', '주문금액', '결제금액', '쿠팡부담할인금액', '상점부담할인금액', '서비스수수료', '카드수수료_결제이용료', '배달수수료', '주문중개수수료', '배달요금', '고객부담배달비총액', '프로모션혜택금액', '총공급가액', '총부가세액', '최종요금총액', '정산금액'

# %% [markdown]
# ## 거래 시간 분류

# %% [markdown]
# **DAY**: 12:00 ~ 14:59<br>
# **MID**: 15:00 ~ 16:59<br>
# **EVENING**: 17:00 ~ 20:00

# %%
def time_split(js_data):
    for i in range(0, len(js_data)):
        if (js_data.loc[i, '거래일시'].time()<time(15, 0)):
            js_data.loc[i, '주문시간대']='DAY'
        elif (js_data.loc[i, '거래일시'].time()<time(17, 0)):
            js_data.loc[i, '주문시간대']='MID'
        else:
            js_data.loc[i, '주문시간대']='EVENING'

# %%
time_split(js_q1)
time_split(js_q2)
time_split(js_q3)

# %%
print('Q1')
print(js_q1.groupby('주문시간대')['주문시간대'].count())

print('Q2')
print(js_q2.groupby('주문시간대')['주문시간대'].count())

print('Q3')
print(js_q3.groupby('주문시간대')['주문시간대'].count())
# Out:
# Q1
# 주문시간대
# DAY        103
# EVENING     28
# MID         47
# Name: 주문시간대, dtype: int64
# Q2
# 주문시간대
# DAY        161
# EVENING     33
# MID         70
# Name: 주문시간대, dtype: int64
# Q3
# 주문시간대
# DAY        181
# EVENING     39
# MID         51
# Name: 주문시간대, dtype: int64

# %% [markdown]
# ## 결제 후 취소한 건 처리

# %%
def drop_pay(js_data):
    js_cancel = js_data[js_data.거래유형=='CANCEL']['주문아이디'].values.tolist()
    temp=js_data[js_data['주문아이디'].isin(js_cancel)]
    idx = temp[temp.거래유형=='PAY']['거래유형'].index
    js_data.drop(idx, axis=0, inplace=True)

# %%
print('삭제전\n\nQ1')
print(js_q1.groupby('거래유형')['거래유형'].count())

print('Q2')
print(js_q2.groupby('거래유형')['거래유형'].count())

print('Q3')
print(js_q3.groupby('거래유형')['거래유형'].count())
# Out:
# 삭제전
#
# Q1
# 거래유형
# CANCEL      5
# PAY       173
# Name: 거래유형, dtype: int64
# Q2
# 거래유형
# CANCEL      8
# PAY       256
# Name: 거래유형, dtype: int64
# Q3
# 거래유형
# CANCEL     10
# PAY       261
# Name: 거래유형, dtype: int64

# %%
drop_pay(js_q1)
drop_pay(js_q2)
drop_pay(js_q3)

# %%
print('삭제후\n\nQ1')
print(js_q1.groupby('거래유형')['거래유형'].count())

print('Q2')
print(js_q2.groupby('거래유형')['거래유형'].count())

print('Q3')
print(js_q3.groupby('거래유형')['거래유형'].count())
# Out:
# 삭제후
#
# Q1
# 거래유형
# CANCEL      5
# PAY       168
# Name: 거래유형, dtype: int64
# Q2
# 거래유형
# CANCEL      8
# PAY       248
# Name: 거래유형, dtype: int64
# Q3
# 거래유형
# CANCEL     10
# PAY       251
# Name: 거래유형, dtype: int64

# %% [markdown]
# ## 빵 종류별 주문 및 취소

# %%
# 빵 리스트 만들기
import re
bread_list=[]
js_2021['주문내역'].apply(lambda x: bread_list.extend(list(x.split(', '))))
for i in range(len(bread_list)):
    bread_list[i] = re.sub('x[0-9]', '', bread_list[i])
bread_list = list(set(bread_list))

# %%
bread_list
# Out:
# ['크로와상',
#  '녹차 스콘',
#  '뺑오쇼콜라',
#  '스콘',
#  '레몬 마들렌',
#  '사워도우',
#  '치아바타',
#  '빵드미',
#  '크렌베리 스콘',
#  '곡물 치아바타',
#  '아몬드 크로와상',
#  '올리브오일',
#  '브리오슈',
#  '바질페스토 스콘',
#  '얼그레이 스콘',
#  '바게트',
#  '초코 브리오슈',
#  '블랙올리브 치아바타',
#  '크렌베리 치아바타',
#  '아메리카노',
#  '호두 크렌베리 캉파뉴',
#  '체다치즈',
#  '푸가스 ',
#  '보스톡',
#  '라즈베리 크럼블',
#  '통밀빵',
#  '초코 스콘',
#  '먹물 유자 크림치즈',
#  '먹물 치즈 치아바타',
#  '멀티그레인 빵드미',
#  '카페라떼',
#  '무화과 사워도우',
#  '병아리콩 치아바타']

# %%
# 빵 주문/취소 수량 데이터프레임 만들기
bread_df = pd.DataFrame(index=bread_list)
bread_df['PAY']=0
bread_df['CANCEL']=0
recomm_list=['크로와상', '스콘', '치아바타', '먹물 유자 크림치즈', '먹물 치즈 치아바타']
bread_df['비고']='-'
bread_df.loc[recomm_list, '비고']='추천'

# %%
bread_df
# Out:
#              PAY  CANCEL  비고
# 크로와상           0       0  추천
# 녹차 스콘          0       0   -
# 뺑오쇼콜라          0       0   -
# 스콘             0       0  추천
# 레몬 마들렌         0       0   -
# 사워도우           0       0   -
# 치아바타           0       0  추천
# 빵드미            0       0   -
# 크렌베리 스콘        0       0   -
# 곡물 치아바타        0       0   -
# 아몬드 크로와상       0       0   -
# 올리브오일          0       0   -
# 브리오슈           0       0   -
# 바질페스토 스콘       0       0   -
# 얼그레이 스콘        0       0   -
# 바게트            0       0   -
# 초코 브리오슈        0       0   -
# 블랙올리브 치아바타     0       0   -
# 크렌베리 치아바타      0       0   -
# 아메리카노          0       0   -
# 호두 크렌베리 캉파뉴    0       0   -
# 체다치즈           0       0   -
# 푸가스            0       0   -
# 보스톡            0       0   -
# 라즈베리 크럼블       0       0   -
# 통밀빵            0       0   -
# 초코 스콘          0       0   -
# 먹물 유자 크림치즈     0       0  추천
# 먹물 치즈 치아바타     0       0  추천
# 멀티그레인 빵드미      0       0   -
# 카페라떼           0       0   -
# 무화과 사워도우       0       0   -
# 병아리콩 치아바타      0       0   -

# %% [markdown]
# ### 주문한 빵

# %%
# PAY한 빵
pay_bread=[]
js_2021.loc[js_2021.거래유형=='PAY', '주문내역'].apply(lambda x: pay_bread.extend(list(x.split(', '))))
# Out:
# Series([], Name: 주문내역, dtype: object)

# %%
pay_bread
# Out:
# []

# %%
cnt=1
for i in pay_bread:
    if i.find('x')==-1:
        bread_df.loc[i,'PAY']=bread_df.loc[i,'PAY']+1
    else:
        cnt=int(i[i.find('x')+1:])
        bread_df.loc[i[:i.find('x')], 'PAY']=bread_df.loc[i[:i.find('x')], 'PAY']+cnt

# %%
bread_df
# Out:
#              PAY  CANCEL  비고
# 크로와상           0       0  추천
# 녹차 스콘          0       0   -
# 뺑오쇼콜라          0       0   -
# 스콘             0       0  추천
# 레몬 마들렌         0       0   -
# 사워도우           0       0   -
# 치아바타           0       0  추천
# 빵드미            0       0   -
# 크렌베리 스콘        0       0   -
# 곡물 치아바타        0       0   -
# 아몬드 크로와상       0       0   -
# 올리브오일          0       0   -
# 브리오슈           0       0   -
# 바질페스토 스콘       0       0   -
# 얼그레이 스콘        0       0   -
# 바게트            0       0   -
# 초코 브리오슈        0       0   -
# 블랙올리브 치아바타     0       0   -
# 크렌베리 치아바타      0       0   -
# 아메리카노          0       0   -
# 호두 크렌베리 캉파뉴    0       0   -
# 체다치즈           0       0   -
# 푸가스            0       0   -
# 보스톡            0       0   -
# 라즈베리 크럼블       0       0   -
# 통밀빵            0       0   -
# 초코 스콘          0       0   -
# 먹물 유자 크림치즈     0       0  추천
# 먹물 치즈 치아바타     0       0  추천
# 멀티그레인 빵드미      0       0   -
# 카페라떼           0       0   -
# 무화과 사워도우       0       0   -
# 병아리콩 치아바타      0       0   -

# %% [markdown]
# ### 취소한 빵

# %%
# CANCEL한 빵
cancel_bread=[]
js_2021.loc[js_2021.거래유형=='CANCEL', '주문내역'].apply(lambda x: cancel_bread.extend(list(x.split(', '))))
# Out:
# Series([], Name: 주문내역, dtype: object)

# %%
cancel_bread
# Out:
# []

# %%
cnt=1
for i in cancel_bread:
    if i.find('x')==-1:
        bread_df.loc[i,'CANCEL']=bread_df.loc[i,'CANCEL']+1
    else:
        cnt=int(i[i.find('x')+1:])
        bread_df.loc[i[:i.find('x')], 'CANCEL']=bread_df.loc[i[:i.find('x')], 'CANCEL']+cnt

# %%
bread_df
# Out:
#              PAY  CANCEL  비고
# 크로와상           0       0  추천
# 녹차 스콘          0       0   -
# 뺑오쇼콜라          0       0   -
# 스콘             0       0  추천
# 레몬 마들렌         0       0   -
# 사워도우           0       0   -
# 치아바타           0       0  추천
# 빵드미            0       0   -
# 크렌베리 스콘        0       0   -
# 곡물 치아바타        0       0   -
# 아몬드 크로와상       0       0   -
# 올리브오일          0       0   -
# 브리오슈           0       0   -
# 바질페스토 스콘       0       0   -
# 얼그레이 스콘        0       0   -
# 바게트            0       0   -
# 초코 브리오슈        0       0   -
# 블랙올리브 치아바타     0       0   -
# 크렌베리 치아바타      0       0   -
# 아메리카노          0       0   -
# 호두 크렌베리 캉파뉴    0       0   -
# 체다치즈           0       0   -
# 푸가스            0       0   -
# 보스톡            0       0   -
# 라즈베리 크럼블       0       0   -
# 통밀빵            0       0   -
# 초코 스콘          0       0   -
# 먹물 유자 크림치즈     0       0  추천
# 먹물 치즈 치아바타     0       0  추천
# 멀티그레인 빵드미      0       0   -
# 카페라떼           0       0   -
# 무화과 사워도우       0       0   -
# 병아리콩 치아바타      0       0   -

# %%
bread_df=bread_df.sort_values(by='PAY', ascending=False)
bread_df
# Out:
#              PAY  CANCEL  비고
# 크로와상           0       0  추천
# 블랙올리브 치아바타     0       0   -
# 무화과 사워도우       0       0   -
# 카페라떼           0       0   -
# 멀티그레인 빵드미      0       0   -
# 먹물 치즈 치아바타     0       0  추천
# 먹물 유자 크림치즈     0       0  추천
# 초코 스콘          0       0   -
# 통밀빵            0       0   -
# 라즈베리 크럼블       0       0   -
# 보스톡            0       0   -
# 푸가스            0       0   -
# 체다치즈           0       0   -
# 호두 크렌베리 캉파뉴    0       0   -
# 아메리카노          0       0   -
# 크렌베리 치아바타      0       0   -
# 초코 브리오슈        0       0   -
# 녹차 스콘          0       0   -
# 바게트            0       0   -
# 얼그레이 스콘        0       0   -
# 바질페스토 스콘       0       0   -
# 브리오슈           0       0   -
# 올리브오일          0       0   -
# 아몬드 크로와상       0       0   -
# 곡물 치아바타        0       0   -
# 크렌베리 스콘        0       0   -
# 빵드미            0       0   -
# 치아바타           0       0  추천
# 사워도우           0       0   -
# 레몬 마들렌         0       0   -
# 스콘             0       0  추천
# 뺑오쇼콜라          0       0   -
# 병아리콩 치아바타      0       0   -

# %%
bread_df.rename(index={'푸가스 ':'푸가스'}, inplace=True)

# %% [markdown]
# # EDA

# %% [markdown]
# **Columns**<br>
# '거래일시', '결제유형', '주문아이디', '거래유형', '주문내역', '총금액', '주문금액', '결제금액', '쿠팡부담할인금액', '상점부담할인금액', '서비스수수료', '카드수수료_결제이용료', '배달수수료', '주문중개수수료', '배달요금', '고객부담배달비총액', '프로모션혜택금액', '총공급가액', '총부가세액', '최종요금총액', '정산금액', '주문시간대'

# %%
js_2021['배달비'] = js_2021.총금액-js_2021.주문금액
js_2021['배달비'].unique()
# Out:
# array([ 3000., -3000.,  6000., -6000.])

# %%
js_2021
# Out:
#                    거래일시    결제유형   주문아이디  거래유형  \
# 0   2021-01-01 12:10:50  CREDIT  1BW780   0.0
# 1   2021-01-01 14:29:07   CHECK  2RJPG0   0.0
# 2   2021-01-01 14:46:06  CREDIT  17XM80   0.0
# 3   2021-01-01 16:39:16    BANK  2RVT80   0.0
# 4   2021-01-01 17:00:55  CREDIT  2VUCR0   1.0
# ..                  ...     ...     ...   ...
# 685 2021-09-29 12:06:56  CREDIT  2695R0   0.0
# 686 2021-09-29 12:12:11  CREDIT  11FPR0   0.0
# 687 2021-09-29 12:46:50  CREDIT  00PBR0   0.0
# 688 2021-09-30 12:40:11  CREDIT  1MXXR0   0.0
# 689 2021-09-30 17:38:23  CREDIT  00X300   1.0
#
#                                                   주문내역      총금액     주문금액  \
# 0             뺑오쇼콜라x2, 크로와상, 치아바타, 먹물 유자 크림치즈, 크렌베리 스콘  22200.0  19200.0
# 1             스콘, 치아바타x2, 호두 크렌베리 캉파뉴, 올리브오일, 레몬 마들렌x2  20000.0  17000.0
# 2    크렌베리 스콘x2, 크렌베리 치아바타x2, 먹물 유자 크림치즈, 아몬드 크로와상, ...  24700.0  21700.0
# 3                       먹물 치즈 치아바타, 뺑오쇼콜라, 크렌베리 치아바타x2  16200.0  13200.0
# 4                            치아바타, 블랙올리브 치아바타, 바게트, 스콘 -15200.0 -12200.0
# ..                                                 ...      ...      ...
# 685  뺑오쇼콜라, 아메리카노, 바게트, 보스톡, 라즈베리 크럼블, 먹물 치즈 치아바타, ...  26600.0  23600.0
# 686                                먹물 치즈 치아바타x2, 뺑오쇼콜라  15300.0  12300.0
# 687                          푸가스 , 먹물 치즈 치아바타, 곡물 치아바타  15300.0  12300.0
# 688                                   크로와상, 스콘x2, 치아바타  15000.0  12000.0
# 689              빵드미, 먹물 치즈 치아바타x2, 블랙올리브 치아바타x2, 치아바타 -25200.0 -22200.0
#
#         결제금액  쿠팡부담할인금액  상점부담할인금액  ... 고객부담배달비총액 프로모션혜택금액  총공급가액 총부가세액 최종요금총액  \
# 0    20200.0    2000.0       0.0  ...    3000.0   5607.0   3849   385   4234
# 1    18000.0    2000.0       0.0  ...    3000.0   5277.0   3783   378   4161
# 2    22700.0    2000.0       0.0  ...    3000.0   5982.0   3924   392   4316
# 3    14200.0    2000.0       0.0  ...    3000.0   4707.0   3669   367   4036
# 4   -13200.0   -2000.0       0.0  ...   -3000.0  -4557.0  -3639  -364  -4003
# ..       ...       ...       ...  ...       ...      ...    ...   ...    ...
# 685  26600.0       0.0       0.0  ...    3000.0   6267.0   3981   398   4379
# 686  15300.0       0.0       0.0  ...    3000.0   4572.0   3642   364   4006
# 687  15300.0       0.0       0.0  ...    3000.0   4572.0   3642   364   4006
# 688  15000.0       0.0       0.0  ...    3000.0   4527.0   3633   363   3996
# 689 -25200.0       0.0       0.0  ...   -3000.0  -6057.0  -3939  -394  -4333
#
#         정산금액    주문시간대     배달비       일매출누계      일매출평균
# 0    14966.0      DAY  3000.0     19200.0        0.0
# 1    12839.0      DAY  3000.0     36200.0        0.0
# 2    17384.0      DAY  3000.0     57900.0        0.0
# 3     9164.0      DAY  3000.0     71100.0        0.0
# 4    -8197.0  EVENING -3000.0     58900.0        0.0
# ..       ...      ...     ...         ...        ...
# 685  19221.0      DAY  3000.0  10679700.0        0.0
# 686   8294.0      DAY  3000.0  10692000.0        0.0
# 687   8294.0      DAY  3000.0  10704300.0  3568100.0
# 688   8004.0      DAY  3000.0  10716300.0        0.0
# 689 -17867.0  EVENING -3000.0  10694100.0        0.0
#
# [690 rows x 25 columns]

# %% [markdown]
# ## 배달비가 3000원 초과인 사람

# %%
js_2021.loc[js_2021.배달비 > 3000, ['주문시간대','총금액', '주문금액', '결제금액', '쿠팡부담할인금액', '서비스수수료', '프로모션혜택금액', '최종요금총액', '정산금액']]
# Out:
#        주문시간대      총금액     주문금액     결제금액  쿠팡부담할인금액 서비스수수료  프로모션혜택금액 최종요금총액  \
# 17       DAY  28800.0  22800.0  28800.0       0.0   3420    6147.0   4352
# 26       DAY  18300.0  12300.0  18300.0       0.0   1845    4572.0   4006
# 30       DAY  18700.0  12700.0  18700.0       0.0   1905    4632.0   4019
# 40   EVENING  19800.0  13800.0  14800.0    5000.0   2070    4797.0   4055
# 90       DAY  19900.0  13900.0  14900.0    5000.0   2085    4812.0   4059
# 137  EVENING  20700.0  14700.0  19700.0    1000.0   2205    4932.0   4085
# 152      DAY  43100.0  37100.0  43100.0       0.0   5565    8292.0   4824
# 186  EVENING  18000.0  12000.0  18000.0       0.0   1800    4527.0   3996
# 218  EVENING  18300.0  12300.0  18300.0       0.0   1845    4572.0   4006
# 221      DAY  22800.0  16800.0  19800.0    3000.0   2520    5247.0   4154
# 257      DAY  18500.0  12500.0  18500.0       0.0   1875    4602.0   4013
# 262      DAY  18000.0  12000.0  18000.0       0.0   1800    4527.0   3996
# 266      DAY  18200.0  12200.0  18200.0       0.0   1830    4557.0   4003
# 285  EVENING  18000.0  12000.0  18000.0       0.0   1800    4527.0   3996
# 288  EVENING  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 291      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 293      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 304      DAY  18200.0  12200.0  18200.0       0.0   1830    4557.0   4003
# 310      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 313      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 326      DAY  18200.0  12200.0  18200.0       0.0   1830    4557.0   4003
# 332      DAY  19000.0  13000.0  19000.0       0.0   1950    4677.0   4029
# 335      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 337      DAY  21100.0  15100.0  21100.0       0.0   2265    4992.0   4098
# 340      DAY  21400.0  15400.0  21400.0       0.0   2310    5037.0   4108
# 343      DAY  21100.0  15100.0  21100.0       0.0   2265    4992.0   4098
# 345      DAY  21400.0  15400.0  21400.0       0.0   2310    5037.0   4108
# 349      DAY  20600.0  14600.0  20600.0       0.0   2190    4917.0   4082
# 357      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 360      DAY  21400.0  15400.0  21400.0       0.0   2310    5037.0   4108
# 363      DAY  21400.0  15400.0  21400.0       0.0   2310    5037.0   4108
# 366      DAY  20400.0  14400.0  20400.0       0.0   2160    4887.0   4075
# 368      DAY  24600.0  18600.0  24600.0       0.0   2790    5517.0   4214
# 369      DAY  21400.0  15400.0  21400.0       0.0   2310    5037.0   4108
# 376      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 378      DAY  24100.0  18100.0  24100.0       0.0   2715    5442.0   4197
# 380      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 382      DAY  48300.0  42300.0  48300.0       0.0   6345    9072.0   4996
# 387      DAY  24100.0  18100.0  24100.0       0.0   2715    5442.0   4197
# 390      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 400      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 405      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 413      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 422      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 431      DAY  18400.0  12400.0  18400.0       0.0   1860    4587.0   4009
# 442      DAY  18700.0  12700.0  14700.0    4000.0   1905    4632.0   4019
# 505      DAY  20300.0  14300.0  20300.0       0.0   2145    4872.0   4072
# 514      DAY  26800.0  20800.0  26800.0       0.0   3120    5847.0   4286
# 517      DAY  37000.0  31000.0  37000.0       0.0   4650    7377.0   4623
# 561      DAY  33500.0  27500.0  33500.0       0.0   4125    6852.0   4508
# 571      DAY  20700.0  14700.0  20700.0       0.0   2205    4932.0   4085
# 598      DAY  21100.0  15100.0  21100.0       0.0   2265    4992.0   4098
# 617      DAY  31700.0  25700.0  27700.0    4000.0   3855    6582.0   4448
# 661      DAY  27800.0  21800.0  27800.0       0.0   3270    5997.0   4319
#
#         정산금액
# 17   18448.0
# 26    8294.0
# 30    8681.0
# 40    9745.0
# 90    9841.0
# 137  10615.0
# 152  32276.0
# 186   8004.0
# 218   8294.0
# 221  12646.0
# 257   8487.0
# 262   8004.0
# 266   8197.0
# 285   8004.0
# 288   8391.0
# 291   8391.0
# 293   8391.0
# 304   8197.0
# 310   8391.0
# 313   8391.0
# 326   8197.0
# 332   8971.0
# 335   8391.0
# 337  11002.0
# 340  11292.0
# 343  11002.0
# 345  11292.0
# 349  10518.0
# 357   8391.0
# 360  11292.0
# 363  11292.0
# 366  10325.0
# 368  14386.0
# 369  11292.0
# 376   8391.0
# 378  13903.0
# 380   8391.0
# 382  37304.0
# 387  13903.0
# 390   8391.0
# 400   8391.0
# 405   8391.0
# 413   8391.0
# 422   8391.0
# 431   8391.0
# 442   8681.0
# 505  10228.0
# 514  16514.0
# 517  26377.0
# 561  22992.0
# 571  10615.0
# 598  11002.0
# 617  21252.0
# 661  17481.0

# %% [markdown]
# - 별 특징적인 모습이 안 보이는 것을 보니 거리가 먼 사람들이 배달비가 높은 듯 함 (6000원)

# %% [markdown]
# ## onehot encoding

# %%
js_2021['거래유형'].replace(['PAY', 'CANCEL'], [0, 1], inplace=True)
js_2021['거래유형'] = js_2021['거래유형'].astype('float')

# %% [markdown]
# ## Heat Map

# %%
sns.heatmap(js_2021.corr(), annot=True, cmap='RdYlGn', linewidths=0.2) #상관관계
fig = plt.gcf()
fig.set_size_inches(10, 8)
plt.show()

# %% [markdown]
# ## 취소 여부 분석

# %% [markdown]
# ### 시간대별 취소

# %%
# 시간대별 취소
print('DAY 취소율: %.2f%%'%(js_2021[js_2021.주문시간대=='DAY'].거래유형.mean()*100))
print('EVENING 취소율: %.2f%%'%(js_2021[js_2021.주문시간대=='EVENING'].거래유형.mean()*100))

pd.crosstab(js_2021.거래유형, js_2021.주문시간대, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# DAY 취소율: 2.34%
# EVENING 취소율: 9.78%
# <style  type="text/css" >
# #T_6703a_row0_col0{
#             background-color:  #068266;
#             color:  #f1f1f1;
#         }#T_6703a_row0_col1{
#             background-color:  #1b8d66;
#             color:  #000000;
#         }#T_6703a_row0_col2{
#             background-color:  #088466;
#             color:  #f1f1f1;
#         }#T_6703a_row1_col0,#T_6703a_row1_col1,#T_6703a_row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_6703a_row2_col0,#T_6703a_row2_col1,#T_6703a_row2_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_6703a_" ><thead>    <tr>        <th class="index_name level0" >주문시간대</th>        <th class="col_heading level0 col0" >DAY</th>        <th class="col_heading level0 col1" >EVENING</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >거래유형</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6703a_level0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_6703a_row0_col0" class="data row0 col0" >584</td>
#                         <td id="T_6703a_row0_col1" class="data row0 col1" >83</td>
#                         <td id="T_6703a_row0_col2" class="data row0 col2" >667</td>
#             </tr>
#             <tr>
#                         <th id="T_6703a_level0_row1" class="row_heading level0 row1" >1.0</th>
#                         <td id="T_6703a_row1_col0" class="data row1 col0" >14</td>
#                         <td id="T_6703a_row1_col1" class="data row1 col1" >9</td>
#                         <td id="T_6703a_row1_col2" class="data row1 col2" >23</td>
#             </tr>
#             <tr>
#                         <th id="T_6703a_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_6703a_row2_col0" class="data row2 col0" >598</td>
#                         <td id="T_6703a_row2_col1" class="data row2 col1" >92</td>
#                         <td id="T_6703a_row2_col2" class="data row2 col2" >690</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - 저녁시간대의 취소율이 높음

# %% [markdown]
# ### 금액별 취소

# %%
js_2021.groupby('거래유형')['주문금액'].mean()
# Out:
# 거래유형
# 0.0    16604.947526
# 1.0   -16582.608696
# Name: 주문금액, dtype: float64

# %% [markdown]
# - 금액과 취소는 큰 의미 없어보임

# %% [markdown]
# ### 할인금액별 취소

# %%
js_2021.groupby('거래유형')['쿠팡부담할인금액'].mean()
# Out:
# 거래유형
# 0.0    331.184408
# 1.0   -290.434783
# Name: 쿠팡부담할인금액, dtype: float64

# %% [markdown]
# ### 배달수수료별 취소

# %%
js_2021.groupby('거래유형')['배달비'].mean()
# Out:
# 거래유형
# 0.0    3242.878561
# 1.0   -3391.304348
# Name: 배달비, dtype: float64

# %% [markdown]
# - 이것도 별 차이 없음

# %% [markdown]
# ### 빵 종류별 취소율

# %%
bread_df
# Out:
#              PAY  CANCEL  비고
# 크로와상           0       0  추천
# 블랙올리브 치아바타     0       0   -
# 무화과 사워도우       0       0   -
# 카페라떼           0       0   -
# 멀티그레인 빵드미      0       0   -
# 먹물 치즈 치아바타     0       0  추천
# 먹물 유자 크림치즈     0       0  추천
# 초코 스콘          0       0   -
# 통밀빵            0       0   -
# 라즈베리 크럼블       0       0   -
# 보스톡            0       0   -
# 푸가스            0       0   -
# 체다치즈           0       0   -
# 호두 크렌베리 캉파뉴    0       0   -
# 아메리카노          0       0   -
# 크렌베리 치아바타      0       0   -
# 초코 브리오슈        0       0   -
# 녹차 스콘          0       0   -
# 바게트            0       0   -
# 얼그레이 스콘        0       0   -
# 바질페스토 스콘       0       0   -
# 브리오슈           0       0   -
# 올리브오일          0       0   -
# 아몬드 크로와상       0       0   -
# 곡물 치아바타        0       0   -
# 크렌베리 스콘        0       0   -
# 빵드미            0       0   -
# 치아바타           0       0  추천
# 사워도우           0       0   -
# 레몬 마들렌         0       0   -
# 스콘             0       0  추천
# 뺑오쇼콜라          0       0   -
# 병아리콩 치아바타      0       0   -

# %%
bread_df['취소율'] = (bread_df.CANCEL / (bread_df.PAY+bread_df.CANCEL))*100
bread_df.sort_values(by='취소율', ascending=False)
# Out:
#              PAY  CANCEL  비고  취소율
# 크로와상           0       0  추천  NaN
# 블랙올리브 치아바타     0       0   -  NaN
# 무화과 사워도우       0       0   -  NaN
# 카페라떼           0       0   -  NaN
# 멀티그레인 빵드미      0       0   -  NaN
# 먹물 치즈 치아바타     0       0  추천  NaN
# 먹물 유자 크림치즈     0       0  추천  NaN
# 초코 스콘          0       0   -  NaN
# 통밀빵            0       0   -  NaN
# 라즈베리 크럼블       0       0   -  NaN
# 보스톡            0       0   -  NaN
# 푸가스            0       0   -  NaN
# 체다치즈           0       0   -  NaN
# 호두 크렌베리 캉파뉴    0       0   -  NaN
# 아메리카노          0       0   -  NaN
# 크렌베리 치아바타      0       0   -  NaN
# 초코 브리오슈        0       0   -  NaN
# 녹차 스콘          0       0   -  NaN
# 바게트            0       0   -  NaN
# 얼그레이 스콘        0       0   -  NaN
# 바질페스토 스콘       0       0   -  NaN
# 브리오슈           0       0   -  NaN
# 올리브오일          0       0   -  NaN
# 아몬드 크로와상       0       0   -  NaN
# 곡물 치아바타        0       0   -  NaN
# 크렌베리 스콘        0       0   -  NaN
# 빵드미            0       0   -  NaN
# 치아바타           0       0  추천  NaN
# 사워도우           0       0   -  NaN
# 레몬 마들렌         0       0   -  NaN
# 스콘             0       0  추천  NaN
# 뺑오쇼콜라          0       0   -  NaN
# 병아리콩 치아바타      0       0   -  NaN

# %% [markdown]
# - 크랜베리 종류들의 취소율이 조금 높음
# - 유의미한지는 흐음..

# %% [markdown]
# ## 빵 종류별 매출

# %%
bread_df['취소율'].mean()
# Out:
# nan

# %%
bread_df.reset_index(inplace=True)
bread_df.rename(columns={'index':'BREAD'}, inplace=True)

# %%
print('평균 취소율:', bread_df['취소율'].mean())
bread_df
# Out:
# 평균 취소율: nan
#           BREAD  PAY  CANCEL  비고  취소율
# 0          크로와상    0       0  추천  NaN
# 1    블랙올리브 치아바타    0       0   -  NaN
# 2      무화과 사워도우    0       0   -  NaN
# 3          카페라떼    0       0   -  NaN
# 4     멀티그레인 빵드미    0       0   -  NaN
# 5    먹물 치즈 치아바타    0       0  추천  NaN
# 6    먹물 유자 크림치즈    0       0  추천  NaN
# 7         초코 스콘    0       0   -  NaN
# 8           통밀빵    0       0   -  NaN
# 9      라즈베리 크럼블    0       0   -  NaN
# 10          보스톡    0       0   -  NaN
# 11          푸가스    0       0   -  NaN
# 12         체다치즈    0       0   -  NaN
# 13  호두 크렌베리 캉파뉴    0       0   -  NaN
# 14        아메리카노    0       0   -  NaN
# 15    크렌베리 치아바타    0       0   -  NaN
# 16      초코 브리오슈    0       0   -  NaN
# 17        녹차 스콘    0       0   -  NaN
# 18          바게트    0       0   -  NaN
# 19      얼그레이 스콘    0       0   -  NaN
# 20     바질페스토 스콘    0       0   -  NaN
# 21         브리오슈    0       0   -  NaN
# 22        올리브오일    0       0   -  NaN
# 23     아몬드 크로와상    0       0   -  NaN
# 24      곡물 치아바타    0       0   -  NaN
# 25      크렌베리 스콘    0       0   -  NaN
# 26          빵드미    0       0   -  NaN
# 27         치아바타    0       0  추천  NaN
# 28         사워도우    0       0   -  NaN
# 29       레몬 마들렌    0       0   -  NaN
# 30           스콘    0       0  추천  NaN
# 31        뺑오쇼콜라    0       0   -  NaN
# 32    병아리콩 치아바타    0       0   -  NaN

# %% [markdown]
# - 압도적으로 추천 빵들이 많이 팔림
# - 매출이 적은 빵들 중에는 하루에 생산되는 양이 적은 것들도 있음

# %% [markdown]
# - **보스톡**: 하루 **10개** 내외로 생산됨
# - **바게트**: 하루 **8개** 생산됨
# - **초코 브리오슈**: 하루 **약 8개** 생산됨
# - **라즈베리크럼블**: 하루 **약 8개** 생산됨
# - **푸가스**: 주중에는 **6개**, 주말에는 **8개** 생산됨
# - **빵드미**: 하루 **7개** 생산됨
# - **멀티그레인 빵드미**: 하루 **7개** 생산됨
# - **통밀빵**: 하루 **4개** 생산됨
# - **사워도우**: 하루 **2개** 생산됨

# %% [markdown]
# - 특히 이런 빵들은 매장에서 먼저 매진되거나 한 두 개가 남아 매진처리되는 경우가 많으므로 이러한 점을 고려해야함

# %% [markdown]
# ### 사진 여부 별 매출

# %%
pic = ['크로와상', '스콘', '치아바타', '먹물 유자 크림치즈', '먹물 치즈 치아바타', '블랙올리브 치아바타']

# %%
bread_df['photo']='-'
bread_df.loc[bread_df.BREAD.isin(pic), 'photo']='사진'

# %%
bread_df
# Out:
#           BREAD  PAY  CANCEL  비고  취소율 photo
# 0          크로와상    0       0  추천  NaN    사진
# 1    블랙올리브 치아바타    0       0   -  NaN    사진
# 2      무화과 사워도우    0       0   -  NaN     -
# 3          카페라떼    0       0   -  NaN     -
# 4     멀티그레인 빵드미    0       0   -  NaN     -
# 5    먹물 치즈 치아바타    0       0  추천  NaN    사진
# 6    먹물 유자 크림치즈    0       0  추천  NaN    사진
# 7         초코 스콘    0       0   -  NaN     -
# 8           통밀빵    0       0   -  NaN     -
# 9      라즈베리 크럼블    0       0   -  NaN     -
# 10          보스톡    0       0   -  NaN     -
# 11          푸가스    0       0   -  NaN     -
# 12         체다치즈    0       0   -  NaN     -
# 13  호두 크렌베리 캉파뉴    0       0   -  NaN     -
# 14        아메리카노    0       0   -  NaN     -
# 15    크렌베리 치아바타    0       0   -  NaN     -
# 16      초코 브리오슈    0       0   -  NaN     -
# 17        녹차 스콘    0       0   -  NaN     -
# 18          바게트    0       0   -  NaN     -
# 19      얼그레이 스콘    0       0   -  NaN     -
# 20     바질페스토 스콘    0       0   -  NaN     -
# 21         브리오슈    0       0   -  NaN     -
# 22        올리브오일    0       0   -  NaN     -
# 23     아몬드 크로와상    0       0   -  NaN     -
# 24      곡물 치아바타    0       0   -  NaN     -
# 25      크렌베리 스콘    0       0   -  NaN     -
# 26          빵드미    0       0   -  NaN     -
# 27         치아바타    0       0  추천  NaN    사진
# 28         사워도우    0       0   -  NaN     -
# 29       레몬 마들렌    0       0   -  NaN     -
# 30           스콘    0       0  추천  NaN    사진
# 31        뺑오쇼콜라    0       0   -  NaN     -
# 32    병아리콩 치아바타    0       0   -  NaN     -

# %% [markdown]
# - 사진이 있는 빵이 추천빵이라서 그런건지 사진 있는 빵들의 주문량이 많음

# %% [markdown]
# - 이름이 생소할 수 있으면서 사진도 없는 빵들의 매출?
# - 호두 크랜베리 캉파뉴, 보스톡, 무화과 사워도우, 브리오슈, 초코 브리오슈, 라즈베리 크럼블, 푸가스, 사워도우

# %%
unknown = ['호두 크렌베리 캉파뉴', '보스톡', '무화과 사워도우', '브리오슈', '초코 브리오슈', '라즈베리 크럼블', '푸가스', '사워도우']
bread_df.loc[bread_df.BREAD.isin(unknown), :]
# Out:
#           BREAD  PAY  CANCEL 비고  취소율 photo
# 2      무화과 사워도우    0       0  -  NaN     -
# 9      라즈베리 크럼블    0       0  -  NaN     -
# 10          보스톡    0       0  -  NaN     -
# 11          푸가스    0       0  -  NaN     -
# 13  호두 크렌베리 캉파뉴    0       0  -  NaN     -
# 16      초코 브리오슈    0       0  -  NaN     -
# 21         브리오슈    0       0  -  NaN     -
# 28         사워도우    0       0  -  NaN     -

# %% [markdown]
# 대부분의 빵들의 주문량이 하위권임 **=> 이름이 생소한 빵들에 사진을 추가해야할 듯**

# %% [markdown]
# ## 할인과 매출

# %%
js_2021.groupby('쿠팡부담할인금액')['주문금액'].agg(['mean', 'count'])
# Out:
#                   mean  count
# 쿠팡부담할인금액
# -2680.0  -13400.000000      1
# -2000.0  -13250.000000      2
#  0.0      15622.838499    613
#  1000.0   14226.666667     15
#  2000.0   15380.000000     15
#  2900.0   14500.000000      1
#  3000.0   16120.000000     20
#  4000.0   19200.000000      2
#  5000.0   16085.714286     21

# %%
plt.figure( figsize=(20,10))
sns.pointplot('쿠팡부담할인금액', '주문금액', data=js_2021)
plt.show()

# %% [markdown]
# - 할인금액이 커진다고 매출이 늘어나는 것은 아닌 듯
# - 그래도 3000원 이상의 쿠폰을 주면 약간의 매출 상승 효과는 있는 것으로 보임

# %% [markdown]
# ## 기간별 매출

# %%
js_pay = js_2021[~(js_2021.거래유형==1)]
js_pay.reset_index(drop=True, inplace=True)
js_cancel = js_2021[~(js_2021.거래유형==0)]
js_cancel.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 일별 매출

# %%
js_pay['일매출누계']=0
js_pay['일매출평균']=0
js_pay.loc[0, '일매출누계'] = js_pay.loc[0, '주문금액']
cnt=0
for i in range(1,len(js_pay)):
    cnt+=1
    
    if (js_pay.loc[i,'거래일시'].day != js_pay.loc[i-1,'거래일시'].day):
        js_pay.loc[i-1, '일매출평균']=round(js_pay.loc[i-1, '일매출누계']/cnt)
        js_pay.loc[i, '일매출누계'] = js_pay.loc[i, '주문금액']
        cnt=0
    else:
        js_pay.loc[i, '일매출누계'] = js_pay.loc[i,'주문금액']+js_pay.loc[i-1, '일매출누계']

# %%
js_pay[js_pay.일매출평균>0]
# Out:
#                    거래일시    결제유형   주문아이디  거래유형  \
# 3   2021-01-01 16:39:16    BANK  2RVT80   0.0
# 4   2021-01-02 15:42:38  CREDIT  1CH400   0.0
# 8   2021-01-03 16:58:35    BANK  1R3W80   0.0
# 10  2021-01-04 15:19:54    BANK  273U80   0.0
# 12  2021-01-05 12:08:58  CREDIT  2EAGG0   0.0
# ..                  ...     ...     ...   ...
# 653 2021-09-25 14:23:32   CHECK  2URB00   0.0
# 655 2021-09-26 16:35:56  CREDIT  0B39R0   0.0
# 658 2021-09-27 17:49:16  CREDIT  0DP4G0   0.0
# 662 2021-09-28 19:54:20    BANK  13V5G0   0.0
# 665 2021-09-29 12:46:50  CREDIT  00PBR0   0.0
#
#                                                   주문내역      총금액     주문금액  \
# 3                       먹물 치즈 치아바타, 뺑오쇼콜라, 크렌베리 치아바타x2  16200.0  13200.0
# 4                      크로와상, 치아바타, 먹물 치즈 치아바타, 크렌베리 스콘  16800.0  13800.0
# 8    먹물 치즈 치아바타, 먹물 유자 크림치즈, 치아바타, 크로와상, 무화과 사워도우, ...  21800.0  18800.0
# 10                                   스콘x2, 초코 스콘, 치아바타  15500.0  12500.0
# 12          스콘, 먹물 치즈 치아바타x3, 녹차 스콘, 얼그레이 스콘, 무화과 사워도우  30500.0  27500.0
# ..                                                 ...      ...      ...
# 653               치아바타, 먹물 치즈 치아바타, 아몬드 크로와상, 라즈베리 크럼블  17700.0  14700.0
# 655                                 먹물 치즈 치아바타x2, 크로와상  15000.0  12000.0
# 658                   크렌베리 치아바타x2, 곡물 치아바타, 크로와상, 치아바타  17900.0  14900.0
# 662           먹물 치즈 치아바타, 크로와상, 레몬 마들렌, 바게트, 크렌베리 치아바타  18200.0  15200.0
# 665                          푸가스 , 먹물 치즈 치아바타, 곡물 치아바타  15300.0  12300.0
#
#         결제금액  쿠팡부담할인금액  상점부담할인금액  ... 고객부담배달비총액 프로모션혜택금액 총공급가액 총부가세액 최종요금총액  \
# 3    14200.0    2000.0       0.0  ...    3000.0   4707.0  3669   367   4036
# 4    14800.0    2000.0       0.0  ...    3000.0   4797.0  3687   368   4055
# 8    19800.0    2000.0       0.0  ...    3000.0   5547.0  3837   383   4220
# 10   10500.0    5000.0       0.0  ...    3000.0   4602.0  3648   365   4013
# 12   30500.0       0.0       0.0  ...    3000.0   6852.0  4098   410   4508
# ..       ...       ...       ...  ...       ...      ...   ...   ...    ...
# 653  14700.0    3000.0       0.0  ...    3000.0   4932.0  3714   371   4085
# 655  15000.0       0.0       0.0  ...    3000.0   4527.0  3633   363   3996
# 658  17900.0       0.0       0.0  ...    3000.0   4962.0  3720   372   4092
# 662  18200.0       0.0       0.0  ...    3000.0   5007.0  3729   373   4102
# 665  15300.0       0.0       0.0  ...    3000.0   4572.0  3642   364   4006
#
#         정산금액    주문시간대     배달비    일매출누계  일매출평균
# 3     9164.0      DAY  3000.0  71100.0  17775
# 4     9745.0      DAY  3000.0  13800.0  13800
# 8    14580.0      DAY  3000.0  60900.0  15225
# 10    8487.0      DAY  3000.0  24700.0  12350
# 12   22992.0      DAY  3000.0  42500.0  21250
# ..       ...      ...     ...      ...    ...
# 653  10615.0      DAY  3000.0  34800.0  17400
# 655   8004.0      DAY  3000.0  32600.0  16300
# 658  10808.0  EVENING  3000.0  64600.0  21533
# 662  11098.0  EVENING  3000.0  57000.0  14250
# 665   8294.0      DAY  3000.0  48200.0  16067
#
# [243 rows x 25 columns]

# %%
plt.figure( figsize=(20,10))
sns.lineplot('거래일시', '일매출평균', data=js_pay[js_pay.일매출평균>0])
plt.show()

# %% [markdown]
# - 일별 매출로 봤을 때는 크게 변화되는 추이 파악 어려움

# %% [markdown]
# ### 월별 매출

# %%
js_pay['월매출평균']=0
cnt=0
for i in range(1,len(js_pay)):    
    if (js_pay.loc[i,'거래일시'].month != js_pay.loc[i-1,'거래일시'].month):
        mnth = js_pay.loc[i, '거래일시'].month
        js_pay.loc[i-1, '월매출평균']=round(js_pay.loc[(js_pay['거래일시']>=datetime(2021, mnth-1, 1))&(js_pay['거래일시']<datetime(2021, mnth, 1)), '주문금액'].mean())
        
js_pay.loc[len(js_pay)-1, '월매출평균']=round(js_pay.loc[(js_pay['거래일시']>=datetime(2021, 9, 1)), '주문금액'].mean())

# %%
js_pay[js_pay.월매출평균>0]
# Out:
#                    거래일시    결제유형   주문아이디  거래유형  \
# 60  2021-01-31 18:24:05    BANK  0BB0R0   0.0
# 108 2021-02-28 14:42:33  CREDIT  1PGP00   0.0
# 167 2021-03-30 13:44:56    BANK  2TH980   0.0
# 227 2021-04-30 12:59:20   CHECK  2W2WG0   0.0
# 322 2021-05-31 17:14:44  CREDIT  0TW7R0   0.0
# 415 2021-06-30 13:08:12  CREDIT  1S2780   0.0
# 488 2021-07-31 16:11:06    BANK  0JU8G0   0.0
# 582 2021-08-31 16:34:42    BANK  0AEK80   0.0
# 666 2021-09-30 12:40:11  CREDIT  1MXXR0   0.0
#
#                                                   주문내역      총금액     주문금액  \
# 60                                      크로와상x2, 치아바타x2  15000.0  12000.0
# 108                  크로와상x2, 뺑오쇼콜라, 초코 스콘, 브리오슈x2, 빵드미  26600.0  23600.0
# 167              먹물 치즈 치아바타x3, 블랙올리브 치아바타x2, 크렌베리 치아바타  24600.0  21600.0
# 227                    뺑오쇼콜라, 아몬드 크로와상, 브리오슈, 레몬 마들렌x2  16000.0  13000.0
# 322                             크로와상, 치아바타x2, 아몬드 크로와상  15700.0  12700.0
# 415  치아바타, 아몬드 크로와상, 초코 브리오슈, 무화과 사워도우, 라즈베리 크럼블, 푸가스   24800.0  21800.0
# 488                                 크로와상x3, 먹물 치즈 치아바타  16500.0  13500.0
# 582               먹물 치즈 치아바타, 올리브오일, 얼그레이 스콘, 아몬드 크로와상  15700.0  12700.0
# 666                                   크로와상, 스콘x2, 치아바타  15000.0  12000.0
#
#         결제금액  쿠팡부담할인금액  상점부담할인금액  ... 프로모션혜택금액 총공급가액 총부가세액 최종요금총액     정산금액  \
# 60   15000.0       0.0       0.0  ...   4527.0  3633   363   3996   8004.0
# 108  26600.0       0.0       0.0  ...   6267.0  3981   398   4379  19221.0
# 167  24600.0       0.0       0.0  ...   5967.0  3921   392   4313  17287.0
# 227  16000.0       0.0       0.0  ...   4677.0  3663   366   4029   8971.0
# 322  15700.0       0.0       0.0  ...   4632.0  3654   365   4019   8681.0
# 415  24800.0       0.0       0.0  ...   5997.0  3927   392   4319  17481.0
# 488  16500.0       0.0       0.0  ...   4752.0  3678   368   4046   9454.0
# 582  15700.0       0.0       0.0  ...   4632.0  3654   365   4019   8681.0
# 666  15000.0       0.0       0.0  ...   4527.0  3633   363   3996   8004.0
#
#        주문시간대     배달비    일매출누계  일매출평균  월매출평균
# 60   EVENING  3000.0  97500.0  19500  16708
# 108      DAY  3000.0  35900.0  17950  16438
# 167      DAY  3000.0  21600.0  21600  16708
# 227      DAY  3000.0  41600.0  13867  16658
# 322  EVENING  3000.0  72400.0  14480  16889
# 415      DAY  3000.0  39200.0  19600  16466
# 488      DAY  3000.0  45600.0  15200  15286
# 582      DAY  3000.0  72200.0  14440  16612
# 666      DAY  3000.0  12000.0      0  17486
#
# [9 rows x 26 columns]

# %%
plt.figure( figsize=(20,10))
sns.lineplot('거래일시', '월매출평균', data=js_pay[js_pay.월매출평균>0])
plt.xticks([datetime(2021,1,31), datetime(2021,2,28), datetime(2021,3,31),datetime(2021,4,30),datetime(2021,5,31),datetime(2021,6,30),datetime(2021,7,31),datetime(2021,8,31),datetime(2021,9,30)],
           ['1월', '2월','3월','4월','5월','6월','7월','8월','9월'], size=15)
plt.show()

# %% [markdown]
# - 매출이 점차 증가하는 듯 보이긴 하지만 1000원 내외로 매우 근소한 차이임
# - 7월 매출의 감소는 왜?

# %% [markdown]
# ### 분기별 매출

# %%
print(js_q1.loc[js_q1.거래유형=='PAY', '주문금액'].mean())
print(js_q2.loc[js_q2.거래유형=='PAY', '주문금액'].mean())
print(js_q3.loc[js_q3.거래유형=='PAY', '주문금액'].mean())
# Out:
# 16630.95238095238
# 16674.59677419355
# 16518.725099601594

# %% [markdown]
# - 역시나 증가 없음

# %% [markdown]
# ### 시간대별 매출

# %%
print(js_2021.loc[js_2021.주문시간대=='DAY', '주문금액'].mean())
print(js_2021.loc[js_2021.주문시간대=='MID', '주문금액'].mean())
print(js_2021.loc[js_2021.주문시간대=='EVENING', '주문금액'].mean())
# Out:
# 15908.695652173914
# nan
# 12833.695652173914
